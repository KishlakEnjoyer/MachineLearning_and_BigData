# %%
import pandas as pd

# %% [markdown]
# # Датасет сайта Kinoviews

# %%
dfkino = pd.read_csv('parsing_datasets/htmldf.csv')

# %%
dfkino.head()
# Out:
#    idFilm                 titleRU                   titleEN  yearPub  \
# 0       1       Побег из Шоушенка  The Shawshank Redemption     1994
# 1       2           Крестный отец             The Godfather     1972
# 2       3           Темный рыцарь           The Dark Knight     2008
# 3       4         Крестный отец 2    The Godfather: Part II     1974
# 4       5  12 разгневанных мужчин              12 Angry Men     1957
#
#                                          description    chrono country  \
# 0  "Побег из Шоушенка" - фильм, который считается...  142 мин.     США
# 1  Фильм, ставший классикой своего жанра, рассказ...  175 мин.     США
# 2  Бэтман вершит правосудие в Готэме. Его партнер...  152 мин.     США
# 3  Продолжение эпохальной саги режиссера Френсиса...  202 мин.     США
# 4  Один из 12 присяжных  в деле об убийстве пытае...   96 мин.     США
#
#                                           genre              producer  \
# ...

# %%
dfkino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   idFilm       250 non-null    int64
#  1   titleRU      250 non-null    object
#  2   titleEN      250 non-null    object
#  3   yearPub      250 non-null    int64
#  4   description  250 non-null    object
#  5   chrono       250 non-null    object
#  6   country      250 non-null    object
#  7   genre        250 non-null    object
#  8   producer     250 non-null    object
#  9   starActor1   250 non-null    object
#  10  starActor2   250 non-null    object
#  11  rating       250 non-null    float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 23.6+ KB

# %% [markdown]
# # Датасет JSON файлов

# %%
dfjson = pd.read_csv('parsing_datasets/jsondf.csv')

# %%
dfjson.head()
# Out:
#              name_company  rate_company  subscribers      industries  \
# 0  Cybersport.Metaratings           0.0            0  Нет информации
# 1         ESforce Holding           0.0            0  Нет информации
# 2         ESforce Holding           0.0            0  Нет информации
# 3         ESforce Holding           0.0            0  Нет информации
# 4         ESforce Holding           0.0            0  Нет информации
#
#   about_company                                               text  \
# 0    Неизвестно  7 декабря состоялась церемония награждения лау...
# 1    Неизвестно  7 декабря состоялась церемония награждения лау...
# 2    Неизвестно  Из совместного исследования издателя компьютер...
# 3    Неизвестно  По статистике The Esports Observer за I полови...
# 4    Неизвестно  Компании SuperData Research и PayPal провели с...
#
#           publish_date  rate_post  views_post  refs_quant
# 0  2025-12-08 09:30:00          6        2300           1
# ...

# %%
dfjson.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1112 entries, 0 to 1111
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name_company   1112 non-null   object
#  1   rate_company   1112 non-null   float64
#  2   subscribers    1112 non-null   int64
#  3   industries     1112 non-null   object
#  4   about_company  1112 non-null   object
#  5   text           1112 non-null   object
#  6   publish_date   1111 non-null   object
#  7   rate_post      1112 non-null   int64
#  8   views_post     1112 non-null   int64
#  9   refs_quant     1112 non-null   int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 87.0+ KB

# %% [markdown]
# # Датасет PDF файлов

# %%
dfpdf = pd.read_csv('parsing_datasets/pdfdf.csv')

# %%
dfpdf.head()
# Out:
#                                                title  \
# 0  Cocoapods, Carthage, SPM как выбрать менеджер ...
# 1  Deutsche Telekom и Perplexity объявили о новом...
# 2              imgonline-com-ua-site2pdfB28eKGLy6EjA
# 3  OpenAI отходит от теории внезапного прорыва в ...
# 4  OSINT & Hacking — как работает фишинг для нель...
#
#                  name_company  rating date_publish  \
# 0               red_mad_robot  117.94   2023-03-20
# 1  Технократия @technokratiya    4.40   2025-03-03
# 2                     Cloud4Y   71.07   2023-03-20
# 3                      BotHub  459.20   2025-03-07
# 4                     Cloud4Y   71.07   2023-03-20
#
#                                             activity  \
# 0       №1 в разработке цифровых решений для бизнеса
# 1                                        ИТ-Компания
# 2                #1 Корпоративный облачный провайдер
# 3  Агрегатор нейросетей: ChatGPT, Claude, Midjourney
# 4                #1 Корпоративный облачный провайдер
#
# ...

# %%
dfpdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         23 non-null     object
#  1   name_company  23 non-null     object
#  2   rating        23 non-null     float64
#  3   date_publish  23 non-null     object
#  4   activity      23 non-null     object
#  5   text_article  23 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 1.2+ KB
