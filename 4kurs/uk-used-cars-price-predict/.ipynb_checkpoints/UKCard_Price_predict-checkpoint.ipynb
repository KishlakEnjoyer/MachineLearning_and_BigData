# %% [markdown]
# # 🚙 Прогнозирование цен на поддержанные автомобили в Великобритании

# %% [markdown]
# # 1. Подключение библиотек

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# инструмент для поиска лучших гиперпараметров
from sklearn.model_selection import GridSearchCV

#импортируем модели для их обучения
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

# %%
audi_df = pd.read_csv("audi.csv")
ford_df = pd.read_csv("ford.csv")
bmw_df = pd.read_csv("bmw.csv")
toyota_df = pd.read_csv("toyota.csv")

# %%
audi_df.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
bmw_df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
ford_df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
toyota_df.head()
# Out:
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3   GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4   GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0

# %% [markdown]
# Почему то на платформе Kaggle скачались датасеты раздельно, поэтому сейчас объединим датасеты

# %%
toyota_df['brand'] = 'Toyota'
bmw_df['brand'] = 'BMW'
ford_df['brand'] = 'Ford'
audi_df['brand'] = 'Audi'

# %%
toyota_df.head()
# Out:
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize  \
# 0   GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3   GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4   GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0
#
#     brand
# 0  Toyota
# 1  Toyota
# 2  Toyota
# 3  Toyota
# 4  Toyota

# %% [markdown]
# теперь объединим датасеты

# %%
df = pd.concat([audi_df, bmw_df, ford_df, toyota_df], ignore_index=True)

# %%
df.sample(10)
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 18784         X4  2016  20470    Automatic    52131   Diesel  150  54.3
# 36816     Fiesta  2018   9689       Manual    11000   Petrol  145  55.4
# 42562      Auris  2016   9995    Automatic    87212   Hybrid    0  78.5
# 26430        Ka+  2017   7500       Manual    14689   Petrol  145  57.7
# 31167     Fiesta  2019  13500       Manual    14839   Petrol  145  58.9
# 33731       Kuga  2019  17400       Manual     9397   Diesel  145  45.6
# 25035     Fiesta  2016   9990       Manual     9562   Petrol    0  65.7
# 12446   5 Series  2016  13465    Semi-Auto    71203   Diesel  125  60.1
# 38514     Fiesta  2009   3695       Manual    45962   Petrol  145  49.6
# 43349       Aygo  2015   5610       Manual    33344   Petrol    0  69.0
#
#        engineSize   brand
# 18784         2.0     BMW
# 36816         1.1    Ford
# 42562         1.8  Toyota
# 26430         1.2    Ford
# 31167         1.0    Ford
# 33731         1.5    Ford
# 25035         1.0    Ford
# 12446         2.0     BMW
# 38514         1.2    Ford
# 43349         1.0  Toyota

# %%
# Красоту наводим
new_order = ['brand'] + [col for col in df.columns if col not in ['brand', 'price']] + ['price']
df = df[new_order]

# %%
df.sample(10)
# Out:
#         brand      model  year transmission  mileage fuelType  tax   mpg  \
# 24167    Ford       Kuga  2017       Manual    16735   Diesel  150  60.1
# 45027  Toyota       C-HR  2019       Manual    11759   Petrol  145  41.5
# 8264     Audi         A3  2017       Manual    36974   Petrol   30  60.1
# 25659    Ford   EcoSport  2017       Manual    15818   Petrol  145  53.3
# 26023    Ford     Fiesta  2017       Manual    40176   Diesel  145  88.3
# 476      Audi         A7  2019    Semi-Auto      933   Diesel  145  45.6
# 33682    Ford      Focus  2018       Manual     2500   Diesel  145  74.3
# 17887     BMW   3 Series  2019    Semi-Auto     3150   Petrol  145  42.2
# 19296     BMW   1 Series  2013    Automatic    35000   Diesel   30  64.2
# 24530    Ford      Focus  2019    Automatic     3418   Diesel  145  54.3
#
#        engineSize  price
# 24167         2.0  16688
# 45027         1.2  19495
# 8264          1.4  17000
# 25659         1.0   9790
# 26023         1.5   9998
# 476           2.0  41995
# 33682         1.5  14199
# 17887         2.0  29995
# 19296         2.0  10400
# 24530         1.5  19160

# %% [markdown]
# ## Описание данных
#
# - brand — марка (Ford, BMW, Audi и др.)
# - model — модель (Focus, Q5, 3 Series и др.)
# - year — год выпуска
# - transmission — коробка передач (Manual, Automatic, Semi-Auto)
# - mileage — пробег в милях
# - fuelType — тип топлива (Petrol, Diesel, Hybrid, Electric)
# - tax — дорожный налог в £/год
# - mpg — расход топлива (мили на галлон)
# - engineSize — объём двигателя в литрах
# - price — цена в £

# %%
df.shape
# Out:
# (46152, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46152 entries, 0 to 46151
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         46152 non-null  object
#  1   model         46152 non-null  object
#  2   year          46152 non-null  int64
#  3   transmission  46152 non-null  object
#  4   mileage       46152 non-null  int64
#  5   fuelType      46152 non-null  object
#  6   tax           46152 non-null  int64
#  7   mpg           46152 non-null  float64
#  8   engineSize    46152 non-null  float64
#  9   price         46152 non-null  int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.5+ MB

# %% [markdown]
# Изучив краткую информацию о датасете, приходим к выводу, что пропусков нет, отлично!

# %%
df.describe().T
# Out:
#               count          mean           std     min      25%      50%  \
# year        46152.0   2016.953003      2.176703  1996.0   2016.0   2017.0
# mileage     46152.0  24126.385162  21848.625930     1.0   7835.0  18454.5
# tax         46152.0    117.834438     66.080120     0.0    125.0    145.0
# mpg         46152.0     56.654754     18.953835     2.8     47.9     56.5
# engineSize  46152.0      1.693290      0.611737     0.0      1.2      1.6
# price       46152.0  17211.224042  10200.905956   495.0  10298.0  14799.0
#
#                  75%       max
# year         2019.00    2060.0
# mileage     33477.25  323000.0
# tax           145.00     580.0
# mpg            64.20     470.8
# engineSize      2.00       6.6
# price       20995.00  145000.0

# %% [markdown]
# Вижу некую аномалию в поле year и price, проверим эти строки и исправим это

# %%
df[df['year'] >= 2020]
# Out:
#         brand          model  year transmission  mileage fuelType  tax   mpg  \
# 198      Audi             Q7  2020    Semi-Auto       10   Diesel  145  33.2
# 220      Audi             Q5  2020    Semi-Auto       10   Petrol  145  32.1
# 223      Audi             Q5  2020    Semi-Auto       10   Petrol  145  30.7
# 224      Audi             A4  2020    Semi-Auto       10   Petrol  145  42.2
# 316      Audi             Q7  2020    Semi-Auto      826   Diesel  145  29.4
# ...       ...            ...   ...          ...      ...      ...  ...   ...
# 46098  Toyota   Land Cruiser  2020    Automatic        4   Diesel  145  30.1
# 46101  Toyota   Land Cruiser  2020    Automatic       27   Diesel  145  30.1
# 46102  Toyota   Land Cruiser  2020    Automatic     1244   Diesel  145  30.1
# 46109  Toyota   Land Cruiser  2020    Automatic     4000   Diesel  150  30.1
# 46129  Toyota          Camry  2020    Automatic    10000   Hybrid  135  52.3
#
#        engineSize  price
# 198           3.0  62985
# 220           2.0  37985
# 223           2.0  47895
# 224           2.0  31985
# 316           4.0  82995
# ...           ...    ...
# 46098         2.8  47885
# 46101         2.8  45950
# 46102         2.8  52990
# 46109         2.8  54550
# 46129         2.5  26490
#
# [1836 rows x 10 columns]

# %%
df[df['price'] > 90000]
# Out:
#       brand      model  year transmission  mileage fuelType  tax   mpg  \
# 1646   Audi         R8  2019    Semi-Auto     4000   Petrol  145  21.4
# 2255   Audi         R8  2020    Semi-Auto       70   Petrol  145  21.1
# 3359   Audi         R8  2019    Automatic      100   Petrol  145  24.1
# 3367   Audi         R8  2019    Automatic     1000   Petrol  145  32.8
# 3711   Audi        RS6  2020    Semi-Auto     3220   Petrol  150  22.1
# 3939   Audi         R8  2019    Automatic     8175   Petrol  145  21.6
# 4179   Audi         R8  2019    Semi-Auto       10   Petrol  150  21.4
# 4391   Audi         R8  2018    Semi-Auto     3800   Petrol  145  23.0
# 4400   Audi        RS6  2020    Semi-Auto     2000   Petrol  145  22.1
# 4742   Audi         R8  2019    Automatic    11936   Petrol  145  21.4
# 4783   Audi         R8  2020    Semi-Auto     2000   Petrol  145  21.1
# 4925   Audi         R8  2019    Semi-Auto      500   Petrol  145  21.4
# 4954   Audi         R8  2019    Automatic     6954   Petrol  145  21.6
# 5303   Audi         R8  2018    Automatic     3562   Petrol  145  23.0
# 5459   Audi         R8  2020    Semi-Auto      333   Petrol  145  21.4
# 5707   Audi         R8  2019    Automatic     2369   Petrol  145  22.6
# 6384   Audi        RS6  2020    Semi-Auto     1500   Petrol  150  22.1
# 7128   Audi         R8  2019    Automatic     3000   Petrol  145  21.4
# 7445   Audi         R8  2019    Semi-Auto     7800   Petrol  145  21.4
# 8630   Audi         R8  2018    Automatic     5044   Petrol  150  23.0
# 10225  Audi        RS6  2020    Automatic     3000   Petrol  145  22.1
# 10468  Audi         R8  2019    Automatic    13663   Petrol  150  21.4
# 14306   BMW   2 Series  2015    Semi-Auto    33419   Diesel   20  68.9
# 16030   BMW         M4  2016    Automatic      771   Petrol  300  33.2
#
#        engineSize   price
# 1646          5.2  129000
# 2255          5.2  137995
# 3359          5.2  125000
# 3367          5.2  135000
# 3711          4.0   97500
# 3939          5.2  112990
# 4179          5.2  137500
# 4391          5.2   93950
# 4400          4.0  102544
# 4742          5.2  117990
# 4783          5.2  145000
# 4925          5.2  125000
# 4954          5.2  109990
# 5303          5.2   94990
# 5459          5.2  133900
# 5707          5.2  116000
# 6384          4.0  109495
# 7128          5.2  119450
# 7445          5.2  119995
# 8630          5.2   95950
# 10225         4.0  104948
# 10468         5.2  125000
# 14306         2.0  123456
# 16030         3.0   99950

# %% [markdown]
# Посмотрели на эти значения, все таки значения правильные, но строчку с аномальным годом все же удалим
# ![image.png](attachment:image.png)

# %%
df = df[df['year'] <= 2020]

# %%
df[df['engineSize'] == 0]
# Out:
#         brand   model  year transmission  mileage fuelType  tax    mpg  \
# 7505     Audi      Q5  2019    Automatic     5886   Petrol  135  117.7
# 7506     Audi      Q3  2019    Automatic     1500   Diesel  145   47.1
# 7516     Audi      Q3  2020       Manual     1500   Petrol  145   40.9
# 7517     Audi      Q3  2020    Automatic     1500   Diesel  145   47.1
# 7518     Audi      Q3  2020    Automatic     1500   Petrol  145   32.5
# ...       ...     ...   ...          ...      ...      ...  ...    ...
# 41959  Toyota   Yaris  2016    Automatic    39909   Hybrid    0   86.0
# 44540  Toyota    Aygo  2019       Manual     3635   Petrol  150   56.5
# 44647  Toyota    Aygo  2019       Manual     8531   Petrol  145   56.5
# 44671  Toyota    Aygo  2019       Manual     5354   Petrol  145   56.5
# 45374  Toyota    C-HR  2017       Manual    46571   Petrol  145   47.1
#
#        engineSize  price
# 7505          0.0  44790
# 7506          0.0  32788
# 7516          0.0  29944
# 7517          0.0  33333
# 7518          0.0  29944
# ...           ...    ...
# 41959         0.0  11000
# 44540         0.0   9800
# 44647         0.0   8000
# 44671         0.0   8000
# 45374         0.0  14300
#
# [161 rows x 10 columns]

# %% [markdown]
# Группируем по бренду и модели, заполняем медианой

# %%
df['engineSize'] = df['engineSize'].replace(0, np.nan)
df['engineSize'] = df.groupby(['brand', 'model'])['engineSize'].transform(
    lambda x: x.fillna(x.median())
)

# %%
df[df['mileage'] > 300000]
# Out:
#      brand model  year transmission  mileage fuelType  tax   mpg  engineSize  \
# 9822  Audi    A6  2008       Manual   323000   Diesel  200  44.1         2.0
#
#       price
# 9822   2490

# %%
df.describe().T
# Out:
#               count          mean           std     min      25%      50%  \
# year        46151.0   2016.952070      2.167483  1996.0   2016.0   2017.0
# mileage     46151.0  24125.720374  21848.395863     1.0   7835.0  18454.0
# tax         46151.0    117.832550     66.079590     0.0    125.0    145.0
# mpg         46151.0     56.655054     18.953931     2.8     47.9     56.5
# engineSize  46151.0      1.698212      0.604838     0.6      1.2      1.6
# price       46151.0  17211.456241  10200.894505   495.0  10298.0  14799.0
#
#                 75%       max
# year         2019.0    2020.0
# mileage     33475.5  323000.0
# tax           145.0     580.0
# mpg            64.2     470.8
# engineSize      2.0       6.6
# price       20995.0  145000.0

# %%
df.hist(figsize = (15,15), bins = 30);

# %%
# Визуализируем цены автомобилей от брендов
sns.barplot(data = df, x = 'brand', y = 'price', palette = 'magma')
plt.xticks(rotation = 'vertical')
plt.show()

# %%
df.sample(5)
# Out:
#         brand    model  year transmission  mileage fuelType  tax   mpg  \
# 21782    Ford   Fiesta  2019       Manual    13351   Petrol  145  58.9
# 17340     BMW       X3  2019    Semi-Auto     5865   Diesel  145  54.3
# 40563  Toyota    Yaris  2017       Manual    28000   Diesel    0  80.7
# 41569  Toyota    Yaris  2019       Manual     8394   Petrol  145  47.9
# 15044     BMW       X2  2020    Semi-Auto      835   Petrol  145  38.7
#
#        engineSize  price
# 21782         1.0  13498
# 17340         2.0  32345
# 40563         1.4   8495
# 41569         1.5  11750
# 15044         2.0  34360

# %%
df.columns
# Out:
# Index(['brand', 'model', 'year', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize', 'price', 'brand_encode', 'model_encode',
#        'transmission_encode', 'fuelType_encode'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
df['brand_encode'] = le.fit_transform(df['brand'])
df['model_encode'] = le.fit_transform(df['model'])
df['transmission_encode'] = le.fit_transform(df['transmission'])
df['fuelType_encode'] = le.fit_transform(df['fuelType'])

# %%
fit_df = df[['brand_encode',
            'model_encode',
            'year',
            'transmission_encode',
            'mileage',
            'fuelType_encode',
            'tax',
            'mpg',
            'engineSize',
            'price'
           ]]

# %%
plt.figure(figsize=(18, 16))
sns.heatmap(fit_df.corr(), annot=True, cmap='Reds')
# Out:
# <Axes: >

# %% [markdown]
# # 3. Обучение моделей

# %%
fit_df.head()
# Out:
#    brand_encode  model_encode  year  transmission_encode  mileage  \
# 0             0             8  2017                    1    15735
# 1             0            13  2016                    0    36203
# 2             0             8  2016                    1    29946
# 3             0            11  2017                    0    25952
# 4             0            10  2019                    1     1998
#
#    fuelType_encode  tax   mpg  engineSize  price
# 0                4  150  55.4         1.4  12500
# 1                0   20  64.2         2.0  16500
# 2                4   30  55.4         1.4  11000
# 3                0  145  67.3         2.0  16800
# 4                4  145  49.6         1.0  17300

# %%
X = fit_df.drop(['price'], axis=1)
y = fit_df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
lrm = LinearRegression()
lrm.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
predictions = lrm.predict(X_test_scaled)
predictions
# Out:
# array([[ 0.1170927 ],
#        [-0.99760223],
#        [-1.21148068],
#        ...,
#        [-0.77476002],
#        [-1.21124542],
#        [-0.52292855]])

# %%
sns.regplot(x=y_test_scaled, y=predictions, line_kws={"color":"black"})
# Out:
# <Axes: >

# %%
metrics.r2_score(y_test_scaled, predictions)
# Out:
# 0.7765569589409027

# %% [markdown]
# ## Нейросеть Keras

# %%
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import EarlyStopping

import tensorflow as tf

# %%
model = models.Sequential([
    layers.Input(shape=(9,)),
    
    layers.Dense(64, activation='relu'),    
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(8, activation='relu'),
    layers.Dense(1)
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss='mse',
    metrics=['mae']
)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 64)                640
#
#  dense_21 (Dense)            (None, 32)                2080
#
#  dense_22 (Dense)            (None, 16)                528
#
#  dense_23 (Dense)            (None, 8)                 136
#
#  dense_24 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 3393 (13.25 KB)
# Trainable params: 3393 (13.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Колбэк на ранюю остановку при малом изменении функции потерь
early_stop = EarlyStopping(monitor='val_loss', patience=10)
callbacks = [early_stop]

# Обучение
history = model.fit(
    X_train_scaled, y_train_scaled,
    validation_data=(X_test_scaled, y_test_scaled),
    epochs=200,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# 1010/1010 [==============================] - 2s 1ms/step - loss: 0.1948 - mae: 0.2913 - val_loss: 0.1082 - val_mae: 0.2069
# Epoch 2/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.1007 - mae: 0.1978 - val_loss: 0.0959 - val_mae: 0.1953
# Epoch 3/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0912 - mae: 0.1891 - val_loss: 0.0891 - val_mae: 0.1864
# Epoch 4/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0860 - mae: 0.1845 - val_loss: 0.0908 - val_mae: 0.1829
# Epoch 5/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0813 - mae: 0.1800 - val_loss: 0.0802 - val_mae: 0.1813
# Epoch 6/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0787 - mae: 0.1773 - val_loss: 0.0787 - val_mae: 0.1804
# Epoch 7/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0761 - mae: 0.1745 - val_loss: 0.0782 - val_mae: 0.1793
# Epoch 8/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0729 - mae: 0.1705 - val_loss: 0.0725 - val_mae: 0.1740
# Epoch 9/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0721 - mae: 0.1695 - val_loss: 0.0721 - val_mae: 0.1740
# Epoch 10/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0695 - mae: 0.1665 - val_loss: 0.0686 - val_mae: 0.1696
# Epoch 11/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0681 - mae: 0.1643 - val_loss: 0.0660 - val_mae: 0.1669
# Epoch 12/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0671 - mae: 0.1633 - val_loss: 0.0634 - val_mae: 0.1608
# Epoch 13/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0663 - mae: 0.1619 - val_loss: 0.0644 - val_mae: 0.1613
# Epoch 14/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0641 - mae: 0.1594 - val_loss: 0.0648 - val_mae: 0.1623
# Epoch 15/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0639 - mae: 0.1594 - val_loss: 0.0658 - val_mae: 0.1596
# Epoch 16/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0635 - mae: 0.1583 - val_loss: 0.0642 - val_mae: 0.1619
# Epoch 17/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0618 - mae: 0.1567 - val_loss: 0.0660 - val_mae: 0.1592
# Epoch 18/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0613 - mae: 0.1564 - val_loss: 0.0617 - val_mae: 0.1584
# Epoch 19/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0607 - mae: 0.1549 - val_loss: 0.0583 - val_mae: 0.1536
# Epoch 20/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0605 - mae: 0.1552 - val_loss: 0.0574 - val_mae: 0.1518
# Epoch 21/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0601 - mae: 0.1539 - val_loss: 0.0579 - val_mae: 0.1526
# Epoch 22/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0599 - mae: 0.1535 - val_loss: 0.0585 - val_mae: 0.1543
# Epoch 23/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0582 - mae: 0.1516 - val_loss: 0.0616 - val_mae: 0.1567
# Epoch 24/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0583 - mae: 0.1515 - val_loss: 0.0595 - val_mae: 0.1545
# Epoch 25/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0578 - mae: 0.1513 - val_loss: 0.0567 - val_mae: 0.1524
# Epoch 26/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0566 - mae: 0.1498 - val_loss: 0.0556 - val_mae: 0.1492
# Epoch 27/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0563 - mae: 0.1491 - val_loss: 0.0569 - val_mae: 0.1514
# Epoch 28/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0556 - mae: 0.1481 - val_loss: 0.0576 - val_mae: 0.1489
# Epoch 29/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0550 - mae: 0.1474 - val_loss: 0.0561 - val_mae: 0.1503
# Epoch 30/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0555 - mae: 0.1474 - val_loss: 0.0550 - val_mae: 0.1486
# Epoch 31/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0549 - mae: 0.1470 - val_loss: 0.0586 - val_mae: 0.1551
# Epoch 32/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0543 - mae: 0.1466 - val_loss: 0.0567 - val_mae: 0.1521
# Epoch 33/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0546 - mae: 0.1466 - val_loss: 0.0560 - val_mae: 0.1513
# Epoch 34/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0540 - mae: 0.1455 - val_loss: 0.0547 - val_mae: 0.1512
# Epoch 35/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0541 - mae: 0.1453 - val_loss: 0.0579 - val_mae: 0.1510
# Epoch 36/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0544 - mae: 0.1461 - val_loss: 0.0532 - val_mae: 0.1468
# Epoch 37/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0533 - mae: 0.1445 - val_loss: 0.0554 - val_mae: 0.1472
# Epoch 38/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0531 - mae: 0.1439 - val_loss: 0.0544 - val_mae: 0.1489
# Epoch 39/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0526 - mae: 0.1441 - val_loss: 0.0542 - val_mae: 0.1449
# Epoch 40/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0525 - mae: 0.1435 - val_loss: 0.0609 - val_mae: 0.1632
# Epoch 41/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0529 - mae: 0.1441 - val_loss: 0.0542 - val_mae: 0.1492
# Epoch 42/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0519 - mae: 0.1432 - val_loss: 0.0527 - val_mae: 0.1467
# Epoch 43/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0526 - mae: 0.1432 - val_loss: 0.0534 - val_mae: 0.1473
# Epoch 44/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0517 - mae: 0.1423 - val_loss: 0.0519 - val_mae: 0.1442
# Epoch 45/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0517 - mae: 0.1425 - val_loss: 0.0518 - val_mae: 0.1448
# Epoch 46/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0510 - mae: 0.1409 - val_loss: 0.0520 - val_mae: 0.1455
# Epoch 47/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0513 - mae: 0.1419 - val_loss: 0.0538 - val_mae: 0.1492
# Epoch 48/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0511 - mae: 0.1415 - val_loss: 0.0538 - val_mae: 0.1471
# Epoch 49/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0509 - mae: 0.1408 - val_loss: 0.0518 - val_mae: 0.1446
# Epoch 50/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0506 - mae: 0.1411 - val_loss: 0.0621 - val_mae: 0.1488
# Epoch 51/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0505 - mae: 0.1405 - val_loss: 0.0524 - val_mae: 0.1441
# Epoch 52/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0506 - mae: 0.1405 - val_loss: 0.0510 - val_mae: 0.1429
# Epoch 53/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0508 - mae: 0.1409 - val_loss: 0.0503 - val_mae: 0.1413
# Epoch 54/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0502 - mae: 0.1399 - val_loss: 0.0528 - val_mae: 0.1471
# Epoch 55/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0502 - mae: 0.1402 - val_loss: 0.0535 - val_mae: 0.1442
# Epoch 56/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0501 - mae: 0.1396 - val_loss: 0.0512 - val_mae: 0.1446
# Epoch 57/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0500 - mae: 0.1398 - val_loss: 0.0498 - val_mae: 0.1416
# Epoch 58/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0496 - mae: 0.1393 - val_loss: 0.0506 - val_mae: 0.1423
# Epoch 59/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0500 - mae: 0.1393 - val_loss: 0.0508 - val_mae: 0.1435
# Epoch 60/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0491 - mae: 0.1384 - val_loss: 0.0517 - val_mae: 0.1471
# Epoch 61/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0491 - mae: 0.1385 - val_loss: 0.0501 - val_mae: 0.1422
# Epoch 62/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0495 - mae: 0.1387 - val_loss: 0.0540 - val_mae: 0.1502
# Epoch 63/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0492 - mae: 0.1390 - val_loss: 0.0498 - val_mae: 0.1434
# Epoch 64/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0488 - mae: 0.1381 - val_loss: 0.0563 - val_mae: 0.1450
# Epoch 65/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0492 - mae: 0.1381 - val_loss: 0.0528 - val_mae: 0.1428
# Epoch 66/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0493 - mae: 0.1384 - val_loss: 0.0510 - val_mae: 0.1422
# Epoch 67/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0488 - mae: 0.1382 - val_loss: 0.0507 - val_mae: 0.1410
# Epoch 68/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0488 - mae: 0.1378 - val_loss: 0.0493 - val_mae: 0.1414
# Epoch 69/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0487 - mae: 0.1382 - val_loss: 0.0514 - val_mae: 0.1442
# Epoch 70/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0488 - mae: 0.1379 - val_loss: 0.0531 - val_mae: 0.1461
# Epoch 71/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0482 - mae: 0.1369 - val_loss: 0.0516 - val_mae: 0.1440
# Epoch 72/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0484 - mae: 0.1373 - val_loss: 0.0514 - val_mae: 0.1430
# Epoch 73/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0482 - mae: 0.1372 - val_loss: 0.0553 - val_mae: 0.1467
# Epoch 74/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0478 - mae: 0.1363 - val_loss: 0.0489 - val_mae: 0.1403
# Epoch 75/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0480 - mae: 0.1365 - val_loss: 0.0499 - val_mae: 0.1425
# Epoch 76/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0478 - mae: 0.1369 - val_loss: 0.0502 - val_mae: 0.1419
# Epoch 77/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0477 - mae: 0.1358 - val_loss: 0.0543 - val_mae: 0.1497
# Epoch 78/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0476 - mae: 0.1362 - val_loss: 0.0493 - val_mae: 0.1403
# Epoch 79/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0478 - mae: 0.1364 - val_loss: 0.0499 - val_mae: 0.1414
# Epoch 80/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0478 - mae: 0.1362 - val_loss: 0.0518 - val_mae: 0.1407
# Epoch 81/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0472 - mae: 0.1357 - val_loss: 0.0514 - val_mae: 0.1432
# Epoch 82/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0472 - mae: 0.1351 - val_loss: 0.0520 - val_mae: 0.1442
# Epoch 83/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0476 - mae: 0.1359 - val_loss: 0.0510 - val_mae: 0.1413
# Epoch 84/200
# 1010/1010 [==============================] - 1s 1ms/step - loss: 0.0475 - mae: 0.1357 - val_loss: 0.0513 - val_mae: 0.1437

# %%
# Визуализация обучения
def plot_history(history):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    # Loss
    axes[0].plot(history.history['loss'], label='Train Loss')
    axes[0].plot(history.history['val_loss'], label='Val Loss')
    axes[0].set_title('Model Loss')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss (MSE)')
    axes[0].legend()
    axes[0].grid(True)
    
    # MAE
    axes[1].plot(history.history['mae'], label='Train MAE')
    axes[1].plot(history.history['val_mae'], label='Val MAE')
    axes[1].set_title('Model MAE')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('MAE')
    axes[1].legend()
    axes[1].grid(True)
    
    plt.tight_layout()
    plt.show()

plot_history(history)

# %%
# Предсказания
y_pred_scaled = model.predict(X_test_scaled).flatten()

# Обратное преобразование масштаба
y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()
y_test_original = scaler_y.inverse_transform(y_test_scaled.reshape(-1, 1)).flatten()
# Out:
# 433/433 [==============================] - 0s 664us/step

# %%
sns.regplot(x=y_test_original, y=y_pred, line_kws={"color":"black"})
# Out:
# <Axes: >

# %%
metrics.r2_score(y_test_original, y_pred)
# Out:
# 0.9489018057522164

# %%
metrics.mean_absolute_error(y_test_original, y_pred)
# Out:
# 1464.893158595961

# %% [markdown]
# # Заключение
# Нейронная модель обучилась лучше чем линейная регрессия, это успех!!
